# %%
import yt_dlp
import json
import os
from datetime import datetime, timedelta
from urllib.error import HTTPError

# %% [markdown]
# This file will download all videos and live streams in the past 24 hours (skipping over any previously downloaded by using the json files within each folder to track the ID's of previously downloaded videos)

# %%
# All channel names (weird name for buccaneers because of they way it is set up)
channel_names = ["49ers", "AtlantaFalcons", "azcardinals", "BaltimoreRavens", "Bengals", "broncos", "browns", "channel/UC0Wwu7r1ybaaR09ANhudTzA", 
                "buffalobills", "CarolinaPanthers", "chargers", "ChicagoBears", "colts", "commandersnfl", "DallasCowboys", 
                "detroitlionsnfl", "eagles", "HoustonTexans", "jaguars", "KansasCityChiefs", "LARams", "MiamiDolphins", 
                "NewOrleansSaints","NewYorkGiants", "nyjets", "packers", "patriots", "raiders", "Seahawks", "steelers", 
                "Titans", "vikings"]

# Path to the directory containing ffmpeg and ffprobe executables (if not in PATH)
ffmpeg_location = 'c:/users/12505/anaconda3/lib/site-packages/ffmpeg/bin'
#Limiting amount of videos to fetch. No need to fetch all the videos
max_videos_to_fetch = 10

# %%
# load the already downloaded videos that have their ids stored in the json file
def load_downloaded_videos(record_file):
    if os.path.exists(record_file):
        with open(record_file, 'r') as f:
            return json.load(f)
    return []

# %%
# will save the ids of any newly downloaded videos within the json file
def save_downloaded_videos(record_file, downloaded_videos):
    with open(record_file, 'w') as f:
        json.dump(downloaded_videos, f)

# %%
# convert the video to audio format using some options ydl offers
def download_audio(url, output_path):
    ydl_opts = {
        'outtmpl': output_path,
        'format': 'bestaudio/best',
        'postprocessors': [{
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'mp3',
            'preferredquality': '192',
        }],
        'ffmpeg_location': ffmpeg_location,  # Specify the path to ffmpeg and ffprobe if necessary
    }
    try:
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            ydl.download([url])
    except Exception as e:
        print(f"Error downloading {url}: {e}")

# %%
# will get the latest videos uploaded to a channel and only select those within a 24 hour period. 
# if the video has already been downloaded the function will skip it.
def get_latest_videos(channel_url, downloaded_videos):
    ydl_opts = {
        'quiet': True,
        'extract_flat': 'in_playlist',
        'playlistend': max_videos_to_fetch,
        'skip_download': True,
    }
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        result = ydl.extract_info(channel_url, download=False)
    one_day_ago = datetime.now() - timedelta(days=1)
    print(one_day_ago)
    new_videos = []
    print(f"Checking {len(result['entries'])} videos from the channel...{channel_url}")

    for entry in result['entries']:
        video_id = entry['id']
        video_url = f"https://www.youtube.com/watch?v={video_id}"
        try:
            # Get detailed info for each video to check upload date
            with yt_dlp.YoutubeDL({'quiet': True}) as ydl:
                video_info = ydl.extract_info(video_url, download=False)
            upload_date = datetime.strptime(video_info['upload_date'], '%Y%m%d')

            if upload_date > one_day_ago and video_id not in downloaded_videos:
                print(f"Adding video {video_url}, uploaded on {upload_date}")
                new_videos.append(video_url)
            else:
                print(f"Skipping video {video_url}, uploaded on {upload_date}")
                break
        except Exception as e:
            print(f"Error processing video {video_url}: {e}")
    
    return new_videos

# %%
# runs and downloads videos appropriately
def main():
    for channel_name in channel_names:
        output_dir = f'videos/{channel_name}/%(title)s.%(ext)s'

        # Path to save the record of downloaded video IDs
        record_file = f'videos/{channel_name}/downloaded_videos.json'

        # Directory to save downloaded audio files
        output_dir = f'videos/{channel_name}/%(title)s.%(ext)s'

        # Channel URL
        if(channel_name == "channel/UC0Wwu7r1ybaaR09ANhudTzA" or channel_name == "detroitlionsnfl"):
            print("here")
            channel_url = f'https://www.youtube.com/{channel_name}/videos'
        else:
            print("yo")
            channel_url = f'https://www.youtube.com/c/{channel_name}/videos'
                    
        # To Get Live Streams
        if(channel_name == "channel/UC0Wwu7r1ybaaR09ANhudTzA" or channel_name == "detroitlionsnfl"):
            print("here1")
            live_url = f'https://www.youtube.com/{channel_name}/streams'
        else:
            print("yo1")
            live_url = f'https://www.youtube.com/c/{channel_name}/streams'
            
        downloaded_videos = load_downloaded_videos(record_file)
        latest_videos = get_latest_videos(channel_url, downloaded_videos)
        latest_live = get_latest_videos(live_url, downloaded_videos)

        try:
            for video_url in latest_videos: #get latest videos
                print(f"Downloading audio for {video_url}")
                download_audio(video_url, output_dir)
                video_id = video_url.split('=')[1]
                downloaded_videos.append(video_id)
                
            for video_url in latest_live: #get latest live streams
                print(f"Downloading audio for {video_url}")
                download_audio(video_url, output_dir)
                video_id = video_url.split('=')[1]
                downloaded_videos.append(video_id)         
            
            save_downloaded_videos(record_file, downloaded_videos)
        except Exception as e: 
            print(f"Error processing video {video_url}: {e}")
            continue
        

if __name__ == "__main__":
    main()
    print("Done!")
# Out:
# yo
# yo1
# 2024-05-27 17:12:17.738178
# Checking 10 videos from the channel...https://www.youtube.com/c/49ers/videos
# Skipping video https://www.youtube.com/watch?v=h89pgQZCqRo, uploaded on 2024-05-22 00:00:00
# 2024-05-27 17:12:20.473957
# Checking 10 videos from the channel...https://www.youtube.com/c/49ers/streams
# Skipping video https://www.youtube.com/watch?v=_5rb4H0LQyY, uploaded on 2024-05-22 00:00:00
# yo
# yo1
# 2024-05-27 17:12:23.156414
# Checking 10 videos from the channel...https://www.youtube.com/c/AtlantaFalcons/videos
# Skipping video https://www.youtube.com/watch?v=stjKRN6_PUI, uploaded on 2024-05-24 00:00:00
# 2024-05-27 17:12:25.761130
# Checking 10 videos from the channel...https://www.youtube.com/c/AtlantaFalcons/streams
# Skipping video https://www.youtube.com/watch?v=q3JtDZFiA8U, uploaded on 2024-05-21 00:00:00
# yo
# yo1
# 2024-05-27 17:12:28.261152
# Checking 10 videos from the channel...https://www.youtube.com/c/azcardinals/videos
# Skipping video https://www.youtube.com/watch?v=Y_trJIafvrg, uploaded on 2024-05-24 00:00:00
# 2024-05-27 17:12:30.965965
# Checking 10 videos from the channel...https://www.youtube.com/c/azcardinals/streams
# Skipping video https://www.youtube.com/watch?v=Nleby7zkVO0, uploaded on 2024-05-20 00:00:00
# yo
# yo1
# 2024-05-27 17:12:33.668980
# Checking 10 videos from the channel...https://www.youtube.com/c/BaltimoreRavens/videos
# Adding video https://www.youtube.com/watch?v=gwhXROOTH1I, uploaded on 2024-05-28 00:00:00
# Adding video https://www.youtube.com/watch?v=Dz50xlkSG5s, uploaded on 2024-05-28 00:00:00
# Adding video https://www.youtube.com/watch?v=7qSO8rkZ0ck, uploaded on 2024-05-28 00:00:00
# Adding video https://www.youtube.com/watch?v=aRYDwQqIzDo, uploaded on 2024-05-28 00:00:00
# Adding video https://www.youtube.com/watch?v=hXXXF750wpg, uploaded on 2024-05-28 00:00:00
# Skipping video https://www.youtube.com/watch?v=XEo6cKx7n5c, uploaded on 2024-05-27 00:00:00
# 2024-05-27 17:12:48.132582
# Checking 10 videos from the channel...https://www.youtube.com/c/BaltimoreRavens/streams
# Adding video https://www.youtube.com/watch?v=mfTqHJLjgF8, uploaded on 2024-05-28 00:00:00
# Skipping video https://www.youtube.com/watch?v=iv7Sq_fd2w0, uploaded on 2024-05-22 00:00:00
# Downloading audio for https://www.youtube.com/watch?v=gwhXROOTH1I
# [youtube] Extracting URL: https://www.youtube.com/watch?v=gwhXROOTH1I
# [youtube] gwhXROOTH1I: Downloading webpage
# [youtube] gwhXROOTH1I: Downloading ios player API JSON
# [youtube] gwhXROOTH1I: Downloading android player API JSON
# [youtube] gwhXROOTH1I: Downloading m3u8 information
# [info] gwhXROOTH1I: Downloading 1 format(s): 251
# [download] Destination: videos\BaltimoreRavens\Mark Andrews Is 'Hungry,' Worked Even Harder This Offseason ｜ Baltimore Ravens Final Drive.webm
# [download] 100% of    2.49MiB in 00:00:00 at 5.82MiB/s
# [ExtractAudio] Destination: videos\BaltimoreRavens\Mark Andrews Is 'Hungry,' Worked Even Harder This Offseason ｜ Baltimore Ravens Final Drive.mp3
# Deleting original file videos\BaltimoreRavens\Mark Andrews Is 'Hungry,' Worked Even Harder This Offseason ｜ Baltimore Ravens Final Drive.webm (pass -k to keep)
# Downloading audio for https://www.youtube.com/watch?v=Dz50xlkSG5s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Dz50xlkSG5s
# [youtube] Dz50xlkSG5s: Downloading webpage
# [youtube] Dz50xlkSG5s: Downloading ios player API JSON
# [youtube] Dz50xlkSG5s: Downloading android player API JSON
# [youtube] Dz50xlkSG5s: Downloading m3u8 information
# [info] Dz50xlkSG5s: Downloading 1 format(s): 251
# [download] Destination: videos\BaltimoreRavens\John and Jim Harbaugh： A Family of Coaches ｜ Baltimore Ravens.webm
# [download] 100% of   20.39MiB in 00:00:01 at 10.72MiB/s
# [ExtractAudio] Destination: videos\BaltimoreRavens\John and Jim Harbaugh： A Family of Coaches ｜ Baltimore Ravens.mp3
# Deleting original file videos\BaltimoreRavens\John and Jim Harbaugh： A Family of Coaches ｜ Baltimore Ravens.webm (pass -k to keep)
# Downloading audio for https://www.youtube.com/watch?v=7qSO8rkZ0ck
# [youtube] Extracting URL: https://www.youtube.com/watch?v=7qSO8rkZ0ck
# [youtube] 7qSO8rkZ0ck: Downloading webpage
# [youtube] 7qSO8rkZ0ck: Downloading ios player API JSON
# [youtube] 7qSO8rkZ0ck: Downloading android player API JSON
# [youtube] 7qSO8rkZ0ck: Downloading m3u8 information
# [info] 7qSO8rkZ0ck: Downloading 1 format(s): 251
# [download] Destination: videos\BaltimoreRavens\Isaiah Likely on the Explosive Offense Weapons ｜ Baltimore Ravens.webm
# [download] 100% of    4.49MiB in 00:00:00 at 7.20MiB/s
# [ExtractAudio] Destination: videos\BaltimoreRavens\Isaiah Likely on the Explosive Offense Weapons ｜ Baltimore Ravens.mp3
# Deleting original file videos\BaltimoreRavens\Isaiah Likely on the Explosive Offense Weapons ｜ Baltimore Ravens.webm (pass -k to keep)
# Downloading audio for https://www.youtube.com/watch?v=aRYDwQqIzDo
# [youtube] Extracting URL: https://www.youtube.com/watch?v=aRYDwQqIzDo
# [youtube] aRYDwQqIzDo: Downloading webpage
# [youtube] aRYDwQqIzDo: Downloading ios player API JSON
# [youtube] aRYDwQqIzDo: Downloading android player API JSON
# [youtube] aRYDwQqIzDo: Downloading m3u8 information
# [info] aRYDwQqIzDo: Downloading 1 format(s): 251
# [download] Destination: videos\BaltimoreRavens\Rashod Bateman Is Leading By Example ｜ Baltimore Ravens.webm
# [download] 100% of    4.67MiB in 00:00:00 at 13.52MiB/s
# [ExtractAudio] Destination: videos\BaltimoreRavens\Rashod Bateman Is Leading By Example ｜ Baltimore Ravens.mp3
# Deleting original file videos\BaltimoreRavens\Rashod Bateman Is Leading By Example ｜ Baltimore Ravens.webm (pass -k to keep)
# Downloading audio for https://www.youtube.com/watch?v=hXXXF750wpg
# [youtube] Extracting URL: https://www.youtube.com/watch?v=hXXXF750wpg
# [youtube] hXXXF750wpg: Downloading webpage
# [youtube] hXXXF750wpg: Downloading ios player API JSON
# [youtube] hXXXF750wpg: Downloading android player API JSON
# [youtube] hXXXF750wpg: Downloading m3u8 information
# [info] hXXXF750wpg: Downloading 1 format(s): 251
# [download] Destination: videos\BaltimoreRavens\Mark Andrews Is ‘Just Hungry’ Going Into the Season  ｜ Baltimore Ravens.webm
# [download] 100% of    6.50MiB in 00:00:00 at 13.92MiB/s
# [ExtractAudio] Destination: videos\BaltimoreRavens\Mark Andrews Is ‘Just Hungry’ Going Into the Season  ｜ Baltimore Ravens.mp3
# Deleting original file videos\BaltimoreRavens\Mark Andrews Is ‘Just Hungry’ Going Into the Season  ｜ Baltimore Ravens.webm (pass -k to keep)
# Downloading audio for https://www.youtube.com/watch?v=mfTqHJLjgF8
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mfTqHJLjgF8
# [youtube] mfTqHJLjgF8: Downloading webpage
# [youtube] mfTqHJLjgF8: Downloading ios player API JSON
# [youtube] mfTqHJLjgF8: Downloading android player API JSON
# [youtube] mfTqHJLjgF8: Downloading m3u8 information
# [info] mfTqHJLjgF8: Downloading 1 format(s): 251
# [download] Destination: videos\BaltimoreRavens\Greg Lewis on What He Sees From the Receiver Room ｜ Baltimore Ravens.webm
# [download] 100% of    5.84MiB in 00:00:00 at 18.91MiB/s
# [ExtractAudio] Destination: videos\BaltimoreRavens\Greg Lewis on What He Sees From the Receiver Room ｜ Baltimore Ravens.mp3
# Deleting original file videos\BaltimoreRavens\Greg Lewis on What He Sees From the Receiver Room ｜ Baltimore Ravens.webm (pass -k to keep)
# yo
# yo1
# 2024-05-27 17:13:46.891212
# Checking 10 videos from the channel...https://www.youtube.com/c/Bengals/videos
# Skipping video https://www.youtube.com/watch?v=eU9C1SzmBvU, uploaded on 2024-05-22 00:00:00
# 2024-05-27 17:13:49.424369
# Checking 10 videos from the channel...https://www.youtube.com/c/Bengals/streams
# Skipping video https://www.youtube.com/watch?v=VesVpNkSaVQ, uploaded on 2024-04-27 00:00:00
# yo
# yo1
# 2024-05-27 17:13:52.108179
# Checking 10 videos from the channel...https://www.youtube.com/c/broncos/videos
# Skipping video https://www.youtube.com/watch?v=cQqZ3wDMuW8, uploaded on 2024-05-24 00:00:00
# 2024-05-27 17:13:54.763183
# Checking 10 videos from the channel...https://www.youtube.com/c/broncos/streams
# Skipping video https://www.youtube.com/watch?v=w-5PE7tK2xg, uploaded on 2024-04-18 00:00:00
# yo
# yo1
# 2024-05-27 17:13:57.481599
# Checking 10 videos from the channel...https://www.youtube.com/c/browns/videos
# Adding video https://www.youtube.com/watch?v=vgTXd7k0H14, uploaded on 2024-05-28 00:00:00
# Skipping video https://www.youtube.com/watch?v=_DYZUREWXAw, uploaded on 2024-05-22 00:00:00
# 2024-05-27 17:14:02.831077
# Checking 10 videos from the channel...https://www.youtube.com/c/browns/streams
# Adding video https://www.youtube.com/watch?v=MsnjB3noF_Y, uploaded on 2024-05-28 00:00:00
# Skipping video https://www.youtube.com/watch?v=VAJy0AtdFH8, uploaded on 2024-05-23 00:00:00
# Downloading audio for https://www.youtube.com/watch?v=vgTXd7k0H14
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vgTXd7k0H14
# [youtube] vgTXd7k0H14: Downloading webpage
# [youtube] vgTXd7k0H14: Downloading ios player API JSON
# [youtube] vgTXd7k0H14: Downloading android player API JSON
# [youtube] vgTXd7k0H14: Downloading m3u8 information
# [info] vgTXd7k0H14: Downloading 1 format(s): 251
# [download] Destination: videos\browns\Meeting Seventh Round Pick Myles Harden ｜ Cleveland Browns.webm
# [download] 100% of   10.41MiB in 00:00:01 at 7.18MiB/s
# [ExtractAudio] Destination: videos\browns\Meeting Seventh Round Pick Myles Harden ｜ Cleveland Browns.mp3
# Deleting original file videos\browns\Meeting Seventh Round Pick Myles Harden ｜ Cleveland Browns.webm (pass -k to keep)
# Downloading audio for https://www.youtube.com/watch?v=MsnjB3noF_Y
# [youtube] Extracting URL: https://www.youtube.com/watch?v=MsnjB3noF_Y
# [youtube] MsnjB3noF_Y: Downloading webpage
# [youtube] MsnjB3noF_Y: Downloading ios player API JSON
# [youtube] MsnjB3noF_Y: Downloading android player API JSON
# [youtube] MsnjB3noF_Y: Downloading m3u8 information
# [info] MsnjB3noF_Y: Downloading 1 format(s): 251
# [download] Destination: videos\browns\ESPN's Jake Trotter Joins the Show ｜ Cleveland Browns Daily.webm
# [download] 100% of   94.82MiB in 00:00:10 at 9.18MiB/s
# [ExtractAudio] Destination: videos\browns\ESPN's Jake Trotter Joins the Show ｜ Cleveland Browns Daily.mp3
# Deleting original file videos\browns\ESPN's Jake Trotter Joins the Show ｜ Cleveland Browns Daily.webm (pass -k to keep)
# here
# here1
# 2024-05-27 17:15:40.642198
# Checking 10 videos from the channel...https://www.youtube.com/channel/UC0Wwu7r1ybaaR09ANhudTzA/videos
# Adding video https://www.youtube.com/watch?v=v0LBAvbIPYI, uploaded on 2024-05-28 00:00:00
# Adding video https://www.youtube.com/watch?v=xqB-gs7dTic, uploaded on 2024-05-28 00:00:00
# Adding video https://www.youtube.com/watch?v=elUE0y7D5GA, uploaded on 2024-05-28 00:00:00
# Adding video https://www.youtube.com/watch?v=cR3ff6k5Ixg, uploaded on 2024-05-28 00:00:00
# Skipping video https://www.youtube.com/watch?v=wWLhqbluwuo, uploaded on 2024-05-23 00:00:00
# 2024-05-27 17:15:52.424848
# Checking 10 videos from the channel...https://www.youtube.com/channel/UC0Wwu7r1ybaaR09ANhudTzA/streams
# Skipping video https://www.youtube.com/watch?v=br20dCL8O_8, uploaded on 2023-06-15 00:00:00
# Downloading audio for https://www.youtube.com/watch?v=v0LBAvbIPYI
# [youtube] Extracting URL: https://www.youtube.com/watch?v=v0LBAvbIPYI
# [youtube] v0LBAvbIPYI: Downloading webpage
# [youtube] v0LBAvbIPYI: Downloading ios player API JSON
# [youtube] v0LBAvbIPYI: Downloading android player API JSON
# [youtube] v0LBAvbIPYI: Downloading m3u8 information
# [info] v0LBAvbIPYI: Downloading 1 format(s): 251
# [download] Destination: videos\channel\UC0Wwu7r1ybaaR09ANhudTzA\Cody Mauch on His Development, Run Game Under Liam Coen ｜ Press Conference ｜ Tampa Bay Buccaneers.webm
# [download] 100% of    4.94MiB in 00:00:00 at 12.42MiB/s
# [ExtractAudio] Destination: videos\channel\UC0Wwu7r1ybaaR09ANhudTzA\Cody Mauch on His Development, Run Game Under Liam Coen ｜ Press Conference ｜ Tampa Bay Buccaneers.mp3
# Deleting original file videos\channel\UC0Wwu7r1ybaaR09ANhudTzA\Cody Mauch on His Development, Run Game Under Liam Coen ｜ Press Conference ｜ Tampa Bay Buccaneers.webm (pass -k to keep)
# Downloading audio for https://www.youtube.com/watch?v=xqB-gs7dTic
# [youtube] Extracting URL: https://www.youtube.com/watch?v=xqB-gs7dTic
# [youtube] xqB-gs7dTic: Downloading webpage
# [youtube] xqB-gs7dTic: Downloading ios player API JSON
# [youtube] xqB-gs7dTic: Downloading android player API JSON
# [youtube] xqB-gs7dTic: Downloading m3u8 information
# [info] xqB-gs7dTic: Downloading 1 format(s): 251
# [download] Destination: videos\channel\UC0Wwu7r1ybaaR09ANhudTzA\K.J. Britt on Stepping Into Role, Using His Voice ｜ Press Conference ｜ Tampa Bay Buccaneers.webm
# [download] 100% of    5.68MiB in 00:00:00 at 14.19MiB/s
# [ExtractAudio] Destination: videos\channel\UC0Wwu7r1ybaaR09ANhudTzA\K.J. Britt on Stepping Into Role, Using His Voice ｜ Press Conference ｜ Tampa Bay Buccaneers.mp3
# Deleting original file videos\channel\UC0Wwu7r1ybaaR09ANhudTzA\K.J. Britt on Stepping Into Role, Using His Voice ｜ Press Conference ｜ Tampa Bay Buccaneers.webm (pass -k to keep)
# Downloading audio for https://www.youtube.com/watch?v=elUE0y7D5GA
# [youtube] Extracting URL: https://www.youtube.com/watch?v=elUE0y7D5GA
# [youtube] elUE0y7D5GA: Downloading webpage
# [youtube] elUE0y7D5GA: Downloading ios player API JSON
# [youtube] elUE0y7D5GA: Downloading android player API JSON
# [youtube] elUE0y7D5GA: Downloading m3u8 information
# [info] elUE0y7D5GA: Downloading 1 format(s): 251
# [download] Destination: videos\channel\UC0Wwu7r1ybaaR09ANhudTzA\Jamel Dean on Tykee Smith ‘Firing On All Cylinders’ ｜ Press Conference ｜ Tampa Bay Buccaneers.webm
# [download] 100% of    4.81MiB in 00:00:00 at 13.45MiB/s
# [ExtractAudio] Destination: videos\channel\UC0Wwu7r1ybaaR09ANhudTzA\Jamel Dean on Tykee Smith ‘Firing On All Cylinders’ ｜ Press Conference ｜ Tampa Bay Buccaneers.mp3
# Deleting original file videos\channel\UC0Wwu7r1ybaaR09ANhudTzA\Jamel Dean on Tykee Smith ‘Firing On All Cylinders’ ｜ Press Conference ｜ Tampa Bay Buccaneers.webm (pass -k to keep)
# Downloading audio for https://www.youtube.com/watch?v=cR3ff6k5Ixg
# [youtube] Extracting URL: https://www.youtube.com/watch?v=cR3ff6k5Ixg
# [youtube] cR3ff6k5Ixg: Downloading webpage
# [youtube] cR3ff6k5Ixg: Downloading ios player API JSON
# [youtube] cR3ff6k5Ixg: Downloading android player API JSON
# [youtube] cR3ff6k5Ixg: Downloading m3u8 information
# [info] cR3ff6k5Ixg: Downloading 1 format(s): 251
# [download] Destination: videos\channel\UC0Wwu7r1ybaaR09ANhudTzA\Todd Bowles Says K.J. Britt is Ready to Lead Defense ｜ Press Conference ｜ Tampa Bay Buccaneers.webm
# [download] 100% of    4.34MiB in 00:00:00 at 14.86MiB/s
# [ExtractAudio] Destination: videos\channel\UC0Wwu7r1ybaaR09ANhudTzA\Todd Bowles Says K.J. Britt is Ready to Lead Defense ｜ Press Conference ｜ Tampa Bay Buccaneers.mp3
# Deleting original file videos\channel\UC0Wwu7r1ybaaR09ANhudTzA\Todd Bowles Says K.J. Britt is Ready to Lead Defense ｜ Press Conference ｜ Tampa Bay Buccaneers.webm (pass -k to keep)
# yo
# yo1
# 2024-05-27 17:16:20.098496
# Checking 10 videos from the channel...https://www.youtube.com/c/buffalobills/videos
# Adding video https://www.youtube.com/watch?v=Nb50EyN2tFI, uploaded on 2024-05-28 00:00:00
# Adding video https://www.youtube.com/watch?v=zeRYqJl-REQ, uploaded on 2024-05-28 00:00:00
# Adding video https://www.youtube.com/watch?v=HSNrUWpTl4Y, uploaded on 2024-05-28 00:00:00
# Adding video https://www.youtube.com/watch?v=dN4nXP1VN2g, uploaded on 2024-05-28 00:00:00
# Skipping video https://www.youtube.com/watch?v=aXt8aBBldZg, uploaded on 2024-05-28 00:00:00
# 2024-05-27 17:16:32.089380
# Checking 10 videos from the channel...https://www.youtube.com/c/buffalobills/streams
# Skipping video https://www.youtube.com/watch?v=eU_pqVsFvRI, uploaded on 2023-06-06 00:00:00
# Downloading audio for https://www.youtube.com/watch?v=Nb50EyN2tFI
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Nb50EyN2tFI
# [youtube] Nb50EyN2tFI: Downloading webpage
# [youtube] Nb50EyN2tFI: Downloading ios player API JSON
# [youtube] Nb50EyN2tFI: Downloading android player API JSON
# [youtube] Nb50EyN2tFI: Downloading m3u8 information
# [info] Nb50EyN2tFI: Downloading 1 format(s): 251
# [download] Destination: videos\buffalobills\Kaiir Elam： “I Trust And Believe In Myself A Lot More Than I Ever Did＂ ｜ Buffalo Bills.webm
# [download] 100% of    6.22MiB in 00:00:00 at 13.54MiB/s
# [ExtractAudio] Destination: videos\buffalobills\Kaiir Elam： “I Trust And Believe In Myself A Lot More Than I Ever Did＂ ｜ Buffalo Bills.mp3
# Deleting original file videos\buffalobills\Kaiir Elam： “I Trust And Believe In Myself A Lot More Than I Ever Did＂ ｜ Buffalo Bills.webm (pass -k to keep)
# Downloading audio for https://www.youtube.com/watch?v=zeRYqJl-REQ
# [youtube] Extracting URL: https://www.youtube.com/watch?v=zeRYqJl-REQ
# [youtube] zeRYqJl-REQ: Downloading webpage
# [youtube] zeRYqJl-REQ: Downloading ios player API JSON
# [youtube] zeRYqJl-REQ: Downloading android player API JSON
# [youtube] zeRYqJl-REQ: Downloading m3u8 information
# [info] zeRYqJl-REQ: Downloading 1 format(s): 251
# [download] Destination: videos\buffalobills\Curtis Samuel： “Be The Best Player That You Possibly Can Be” ｜ Buffalo Bills.webm
# [download] 100% of    3.80MiB in 00:00:00 at 9.55MiB/s
# [ExtractAudio] Destination: videos\buffalobills\Curtis Samuel： “Be The Best Player That You Possibly Can Be” ｜ Buffalo Bills.mp3
# Deleting original file videos\buffalobills\Curtis Samuel： “Be The Best Player That You Possibly Can Be” ｜ Buffalo Bills.webm (pass -k to keep)
# Downloading audio for https://www.youtube.com/watch?v=HSNrUWpTl4Y
# [youtube] Extracting URL: https://www.youtube.com/watch?v=HSNrUWpTl4Y
# [youtube] HSNrUWpTl4Y: Downloading webpage
# [youtube] HSNrUWpTl4Y: Downloading ios player API JSON
# [youtube] HSNrUWpTl4Y: Downloading android player API JSON
# [youtube] HSNrUWpTl4Y: Downloading m3u8 information
# [info] HSNrUWpTl4Y: Downloading 1 format(s): 251
# [download] Destination: videos\buffalobills\Khalil Shakir： ＂What Goes Around Comes Around＂ ｜ Buffalo Bills.webm
# [download] 100% of    9.26MiB in 00:00:01 at 8.57MiB/s
# [ExtractAudio] Destination: videos\buffalobills\Khalil Shakir： ＂What Goes Around Comes Around＂ ｜ Buffalo Bills.mp3
# Deleting original file videos\buffalobills\Khalil Shakir： ＂What Goes Around Comes Around＂ ｜ Buffalo Bills.webm (pass -k to keep)
# Downloading audio for https://www.youtube.com/watch?v=dN4nXP1VN2g
# [youtube] Extracting URL: https://www.youtube.com/watch?v=dN4nXP1VN2g
# [youtube] dN4nXP1VN2g: Downloading webpage
# [youtube] dN4nXP1VN2g: Downloading ios player API JSON
# [youtube] dN4nXP1VN2g: Downloading android player API JSON
# [youtube] dN4nXP1VN2g: Downloading m3u8 information
# [info] dN4nXP1VN2g: Downloading 1 format(s): 251
# [download] Destination: videos\buffalobills\Dalton Kincaid： ＂A Lot of Selfless Guys＂ ｜ Buffalo Bills TE on new-look offense, offseason and more!.webm
# [download] 100% of    4.75MiB in 00:00:00 at 12.25MiB/s
# [ExtractAudio] Destination: videos\buffalobills\Dalton Kincaid： ＂A Lot of Selfless Guys＂ ｜ Buffalo Bills TE on new-look offense, offseason and more!.mp3
# Deleting original file videos\buffalobills\Dalton Kincaid： ＂A Lot of Selfless Guys＂ ｜ Buffalo Bills TE on new-look offense, offseason and more!.webm (pass -k to keep)
# yo
# yo1
# 2024-05-27 17:17:02.327021
# Checking 10 videos from the channel...https://www.youtube.com/c/CarolinaPanthers/videos
# Adding video https://www.youtube.com/watch?v=j8GY7UZRZU8, uploaded on 2024-05-28 00:00:00
# Skipping video https://www.youtube.com/watch?v=ld5zCrwzhLQ, uploaded on 2024-05-23 00:00:00
# 2024-05-27 17:17:07.172841
# Checking 10 videos from the channel...https://www.youtube.com/c/CarolinaPanthers/streams
# Skipping video https://www.youtube.com/watch?v=hVZpWy1jRI0, uploaded on 2022-10-31 00:00:00
# Downloading audio for https://www.youtube.com/watch?v=j8GY7UZRZU8
# [youtube] Extracting URL: https://www.youtube.com/watch?v=j8GY7UZRZU8
# [youtube] j8GY7UZRZU8: Downloading webpage
# [youtube] j8GY7UZRZU8: Downloading ios player API JSON
# [youtube] j8GY7UZRZU8: Downloading android player API JSON
# [youtube] j8GY7UZRZU8: Downloading m3u8 information
# [info] j8GY7UZRZU8: Downloading 1 format(s): 251
# [download] Destination: videos\CarolinaPanthers\Panthers Blueprint 2024 Official Teaser ｜ Carolina Panthers.webm
# [download] 100% of  640.76KiB in 00:00:00 at 2.75MiB/s
# [ExtractAudio] Destination: videos\CarolinaPanthers\Panthers Blueprint 2024 Official Teaser ｜ Carolina Panthers.mp3
# Deleting original file videos\CarolinaPanthers\Panthers Blueprint 2024 Official Teaser ｜ Carolina Panthers.webm (pass -k to keep)
# yo
# yo1
# 2024-05-27 17:17:12.877952
# Checking 10 videos from the channel...https://www.youtube.com/c/chargers/videos
# Adding video https://www.youtube.com/watch?v=Q2u5Fc3AeVE, uploaded on 2024-05-28 00:00:00
# Skipping video https://www.youtube.com/watch?v=yASJ019ReTM, uploaded on 2024-05-24 00:00:00
# 2024-05-27 17:17:17.931457
# Checking 10 videos from the channel...https://www.youtube.com/c/chargers/streams
# Skipping video https://www.youtube.com/watch?v=OGJX72MgGaM, uploaded on 2022-08-11 00:00:00
# Downloading audio for https://www.youtube.com/watch?v=Q2u5Fc3AeVE
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Q2u5Fc3AeVE
# [youtube] Q2u5Fc3AeVE: Downloading webpage
# [youtube] Q2u5Fc3AeVE: Downloading ios player API JSON
# [youtube] Q2u5Fc3AeVE: Downloading android player API JSON
# [youtube] Q2u5Fc3AeVE: Downloading m3u8 information
# [info] Q2u5Fc3AeVE: Downloading 1 format(s): 251
# [download] Destination: videos\chargers\Junior Colson Reacts To Joining The Bolts ｜ LA Chargers.webm
# [download] 100% of    5.78MiB in 00:00:00 at 11.81MiB/s
# [ExtractAudio] Destination: videos\chargers\Junior Colson Reacts To Joining The Bolts ｜ LA Chargers.mp3
# Deleting original file videos\chargers\Junior Colson Reacts To Joining The Bolts ｜ LA Chargers.webm (pass -k to keep)
# yo
# yo1
# 2024-05-27 17:17:27.812760
# Checking 10 videos from the channel...https://www.youtube.com/c/ChicagoBears/videos
# Skipping video https://www.youtube.com/watch?v=pog4odEdLgk, uploaded on 2024-05-24 00:00:00
# 2024-05-27 17:17:30.380367
# Checking 4 videos from the channel...https://www.youtube.com/c/ChicagoBears/streams
# Skipping video https://www.youtube.com/watch?v=G3SCbOTh7fo, uploaded on 2023-10-29 00:00:00
# yo
# yo1
# 2024-05-27 17:17:33.008810
# Checking 10 videos from the channel...https://www.youtube.com/c/colts/videos
# Adding video https://www.youtube.com/watch?v=ZhKGhh50rAY, uploaded on 2024-05-28 00:00:00
# Skipping video https://www.youtube.com/watch?v=_ZST_IGySds, uploaded on 2024-05-24 00:00:00
# 2024-05-27 17:17:37.843921
# Checking 3 videos from the channel...https://www.youtube.com/c/colts/streams
# Skipping video https://www.youtube.com/watch?v=UV-TrxvE0vU, uploaded on 2021-09-19 00:00:00
# Downloading audio for https://www.youtube.com/watch?v=ZhKGhh50rAY
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ZhKGhh50rAY
# [youtube] ZhKGhh50rAY: Downloading webpage
# [youtube] ZhKGhh50rAY: Downloading ios player API JSON
# [youtube] ZhKGhh50rAY: Downloading android player API JSON
# [youtube] ZhKGhh50rAY: Downloading m3u8 information
# [info] ZhKGhh50rAY: Downloading 1 format(s): 251
# [download] Destination: videos\colts\Official Colts Podcast： Anthony Richardson OTA Update.webm
# [download] 100% of   29.03MiB in 00:00:02 at 12.04MiB/s
# [ExtractAudio] Destination: videos\colts\Official Colts Podcast： Anthony Richardson OTA Update.mp3
# Deleting original file videos\colts\Official Colts Podcast： Anthony Richardson OTA Update.webm (pass -k to keep)
# yo
# yo1
# 2024-05-27 17:18:04.781867
# Checking 10 videos from the channel...https://www.youtube.com/c/commandersnfl/videos
# Adding video https://www.youtube.com/watch?v=CKt9ftouNCM, uploaded on 2024-05-28 00:00:00
# Skipping video https://www.youtube.com/watch?v=teQr0RYX-8I, uploaded on 2024-05-27 00:00:00
# 2024-05-27 17:18:10.106337
# Checking 10 videos from the channel...https://www.youtube.com/c/commandersnfl/streams
# Skipping video https://www.youtube.com/watch?v=RgYWjIZZb24, uploaded on 2024-05-22 00:00:00
# Downloading audio for https://www.youtube.com/watch?v=CKt9ftouNCM
# [youtube] Extracting URL: https://www.youtube.com/watch?v=CKt9ftouNCM
# [youtube] CKt9ftouNCM: Downloading webpage
# [youtube] CKt9ftouNCM: Downloading ios player API JSON
# [youtube] CKt9ftouNCM: Downloading android player API JSON
# [youtube] CKt9ftouNCM: Downloading m3u8 information
# [info] CKt9ftouNCM: Downloading 1 format(s): 251
# [download] Destination: videos\commandersnfl\Reacting to NFL Divisional Title Predictions, Virginia HOFers and Get Loud Voicemails ｜ Get Loud.webm
# [download] 100% of   38.73MiB in 00:00:01 at 25.58MiB/s
# [ExtractAudio] Destination: videos\commandersnfl\Reacting to NFL Divisional Title Predictions, Virginia HOFers and Get Loud Voicemails ｜ Get Loud.mp3
# Deleting original file videos\commandersnfl\Reacting to NFL Divisional Title Predictions, Virginia HOFers and Get Loud Voicemails ｜ Get Loud.webm (pass -k to keep)
# yo
# yo1
# 2024-05-27 17:18:43.448927
# Checking 10 videos from the channel...https://www.youtube.com/c/DallasCowboys/videos
# Adding video https://www.youtube.com/watch?v=vDK5yV1myNU, uploaded on 2024-05-28 00:00:00
# Skipping video https://www.youtube.com/watch?v=xHrbU-cxufA, uploaded on 2024-05-24 00:00:00
# 2024-05-27 17:18:48.259856
# Checking 10 videos from the channel...https://www.youtube.com/c/DallasCowboys/streams
# Skipping video https://www.youtube.com/watch?v=JsufZ5YjQKg, uploaded on 2024-05-22 00:00:00
# Downloading audio for https://www.youtube.com/watch?v=vDK5yV1myNU
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vDK5yV1myNU
# [youtube] vDK5yV1myNU: Downloading webpage
# [youtube] vDK5yV1myNU: Downloading ios player API JSON
# [youtube] vDK5yV1myNU: Downloading android player API JSON
# [youtube] vDK5yV1myNU: Downloading m3u8 information
# [info] vDK5yV1myNU: Downloading 1 format(s): 251
# [download] Destination: videos\DallasCowboys\Cowboys StoryLine： Across the Pond ｜ Dallas Cowboys 2024.webm
# [download] 100% of   49.11MiB in 00:00:05 at 9.79MiB/s
# [ExtractAudio] Destination: videos\DallasCowboys\Cowboys StoryLine： Across the Pond ｜ Dallas Cowboys 2024.mp3
# Deleting original file videos\DallasCowboys\Cowboys StoryLine： Across the Pond ｜ Dallas Cowboys 2024.webm (pass -k to keep)
# here
# here1
# 2024-05-27 17:19:34.150336
# Checking 10 videos from the channel...https://www.youtube.com/detroitlionsnfl/videos
# Skipping video https://www.youtube.com/watch?v=8xvUh85T4aw, uploaded on 2024-05-23 00:00:00
# 2024-05-27 17:19:36.667320
# Checking 10 videos from the channel...https://www.youtube.com/detroitlionsnfl/streams
# Skipping video https://www.youtube.com/watch?v=Pj9uIh-Qnw8, uploaded on 2024-05-16 00:00:00
# yo
# yo1
# 2024-05-27 17:19:39.186648
# Checking 10 videos from the channel...https://www.youtube.com/c/eagles/videos
# Skipping video https://www.youtube.com/watch?v=Z7BA2w1C9LU, uploaded on 2024-05-23 00:00:00
# 2024-05-27 17:19:41.860266
# Checking 10 videos from the channel...https://www.youtube.com/c/eagles/streams
# Skipping video https://www.youtube.com/watch?v=Kq7MnHShUwQ, uploaded on 2024-01-15 00:00:00
# yo
# yo1
# 2024-05-27 17:19:44.890243
# Checking 10 videos from the channel...https://www.youtube.com/c/HoustonTexans/videos
# Adding video https://www.youtube.com/watch?v=nkZ0s5R066E, uploaded on 2024-05-28 00:00:00
# Skipping video https://www.youtube.com/watch?v=mcvODB2ZQRo, uploaded on 2024-05-24 00:00:00
# 2024-05-27 17:19:49.803439
# Checking 10 videos from the channel...https://www.youtube.com/c/HoustonTexans/streams
# Skipping video https://www.youtube.com/watch?v=fD1lCL5fMHs, uploaded on 2024-05-21 00:00:00
# Downloading audio for https://www.youtube.com/watch?v=nkZ0s5R066E
# [youtube] Extracting URL: https://www.youtube.com/watch?v=nkZ0s5R066E
# [youtube] nkZ0s5R066E: Downloading webpage
# [youtube] nkZ0s5R066E: Downloading ios player API JSON
# [youtube] nkZ0s5R066E: Downloading android player API JSON
# [youtube] nkZ0s5R066E: Downloading m3u8 information
# [info] nkZ0s5R066E: Downloading 1 format(s): 251
# [download] Destination: videos\HoustonTexans\Major change on the way？.webm
# [download] 100% of   20.81MiB in 00:00:01 at 16.10MiB/s
# [ExtractAudio] Destination: videos\HoustonTexans\Major change on the way？.mp3
# Deleting original file videos\HoustonTexans\Major change on the way？.webm (pass -k to keep)
# yo
# yo1
# 2024-05-27 17:20:08.568027
# Checking 10 videos from the channel...https://www.youtube.com/c/jaguars/videos
# Adding video https://www.youtube.com/watch?v=xxuYIHrrkc4, uploaded on 2024-05-28 00:00:00
# Skipping video https://www.youtube.com/watch?v=17D2yybk50s, uploaded on 2024-05-24 00:00:00
# 2024-05-27 17:20:13.584922
# Checking 10 videos from the channel...https://www.youtube.com/c/jaguars/streams
# Adding video https://www.youtube.com/watch?v=KGlADkep2WQ, uploaded on 2024-05-28 00:00:00
# Adding video https://www.youtube.com/watch?v=T_oMqaZRPd0, uploaded on 2024-05-28 00:00:00
# Skipping video https://www.youtube.com/watch?v=3C2o35gG6fk, uploaded on 2024-05-21 00:00:00
# Downloading audio for https://www.youtube.com/watch?v=xxuYIHrrkc4
# [youtube] Extracting URL: https://www.youtube.com/watch?v=xxuYIHrrkc4
# [youtube] xxuYIHrrkc4: Downloading webpage
# [youtube] xxuYIHrrkc4: Downloading ios player API JSON
# [youtube] xxuYIHrrkc4: Downloading android player API JSON
# [youtube] xxuYIHrrkc4: Downloading m3u8 information
# [info] xxuYIHrrkc4: Downloading 1 format(s): 251
# [download] Destination: videos\jaguars\Gabe Davis, Tyson Campbell on Getting Back to Work ｜ Press Conference ｜ Jacksonville Jaguars.webm
# [download] 100% of    4.54MiB in 00:00:00 at 14.38MiB/s
# [ExtractAudio] Destination: videos\jaguars\Gabe Davis, Tyson Campbell on Getting Back to Work ｜ Press Conference ｜ Jacksonville Jaguars.mp3
# Deleting original file videos\jaguars\Gabe Davis, Tyson Campbell on Getting Back to Work ｜ Press Conference ｜ Jacksonville Jaguars.webm (pass -k to keep)
# Downloading audio for https://www.youtube.com/watch?v=KGlADkep2WQ
# [youtube] Extracting URL: https://www.youtube.com/watch?v=KGlADkep2WQ
# [youtube] KGlADkep2WQ: Downloading webpage
# [youtube] KGlADkep2WQ: Downloading ios player API JSON
# [youtube] KGlADkep2WQ: Downloading android player API JSON
# [youtube] KGlADkep2WQ: Downloading m3u8 information
# [youtube] KGlADkep2WQ: Downloading m3u8 information
# [youtube] KGlADkep2WQ: Downloading MPD manifest
# [info] KGlADkep2WQ: Downloading 1 format(s): 140
# [dashsegments] Total fragments: 411
# [download] Destination: videos\jaguars\Offense, Teaching & Athleticism ｜ Jags A.M. ｜ Jacksonville Jaguars.m4a
# [download] 100% of   32.11MiB in 00:00:40 at 805.93KiB/s
# [FixupM4a] Correcting container of "videos\jaguars\Offense, Teaching & Athleticism ｜ Jags A.M. ｜ Jacksonville Jaguars.m4a"
# [FixupDuplicateMoov] Fixing duplicate MOOV atoms of "videos\jaguars\Offense, Teaching & Athleticism ｜ Jags A.M. ｜ Jacksonville Jaguars.m4a"
# [ExtractAudio] Destination: videos\jaguars\Offense, Teaching & Athleticism ｜ Jags A.M. ｜ Jacksonville Jaguars.mp3
# Deleting original file videos\jaguars\Offense, Teaching & Athleticism ｜ Jags A.M. ｜ Jacksonville Jaguars.m4a (pass -k to keep)
# Downloading audio for https://www.youtube.com/watch?v=T_oMqaZRPd0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=T_oMqaZRPd0
# [youtube] T_oMqaZRPd0: Downloading webpage
# [youtube] T_oMqaZRPd0: Downloading ios player API JSON
# [youtube] T_oMqaZRPd0: Downloading android player API JSON
# [youtube] T_oMqaZRPd0: Downloading m3u8 information
# [info] T_oMqaZRPd0: Downloading 1 format(s): 251
# [download] Destination: videos\jaguars\Doug Pederson and Press Taylor Meet With the Media ｜ Jacksonville Jaguars.webm
# [download] 100% of   22.23MiB in 00:00:00 at 22.25MiB/s
# [ExtractAudio] Destination: videos\jaguars\Doug Pederson and Press Taylor Meet With the Media ｜ Jacksonville Jaguars.mp3
# Deleting original file videos\jaguars\Doug Pederson and Press Taylor Meet With the Media ｜ Jacksonville Jaguars.webm (pass -k to keep)
# yo
# yo1
# 2024-05-27 17:21:44.575852
# Checking 10 videos from the channel...https://www.youtube.com/c/KansasCityChiefs/videos
# Skipping video https://www.youtube.com/watch?v=X5WhVs1foUY, uploaded on 2024-05-24 00:00:00
# 2024-05-27 17:21:47.158401
# Checking 10 videos from the channel...https://www.youtube.com/c/KansasCityChiefs/streams
# ERROR: [youtube] xMwGjr-RVd8: The following content is not available on this app.. Watch on the latest version of YouTube.
# Error processing video https://www.youtube.com/watch?v=xMwGjr-RVd8: ERROR: [youtube] xMwGjr-RVd8: The following content is not available on this app.. Watch on the latest version of YouTube.
# ERROR: [youtube] WmZHCuTBiGA: The following content is not available on this app.. Watch on the latest version of YouTube.
# Error processing video https://www.youtube.com/watch?v=WmZHCuTBiGA: ERROR: [youtube] WmZHCuTBiGA: The following content is not available on this app.. Watch on the latest version of YouTube.
# Skipping video https://www.youtube.com/watch?v=wXvi5ttZfwY, uploaded on 2024-05-22 00:00:00
# yo
# yo1
# 2024-05-27 17:21:51.556794
# Checking 10 videos from the channel...https://www.youtube.com/c/LARams/videos
# Adding video https://www.youtube.com/watch?v=Hd1rs708Z7E, uploaded on 2024-05-28 00:00:00
# Skipping video https://www.youtube.com/watch?v=cAY8uC6QLlA, uploaded on 2024-05-24 00:00:00
# 2024-05-27 17:21:56.317790
# Checking 10 videos from the channel...https://www.youtube.com/c/LARams/streams
# Skipping video https://www.youtube.com/watch?v=o9-p2xDacKc, uploaded on 2024-05-15 00:00:00
# Downloading audio for https://www.youtube.com/watch?v=Hd1rs708Z7E
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Hd1rs708Z7E
# [youtube] Hd1rs708Z7E: Downloading webpage
# [youtube] Hd1rs708Z7E: Downloading ios player API JSON
# [youtube] Hd1rs708Z7E: Downloading android player API JSON
# [youtube] Hd1rs708Z7E: Downloading m3u8 information
# [info] Hd1rs708Z7E: Downloading 1 format(s): 251
# [download] Destination: videos\LARams\Stetson Bennett, DC Chris Shula & OC Mike LaFleur Address The Media As Rams Kick Off Week 2 Of OTAs.webm
# [download] 100% of   13.94MiB in 00:00:02 at 5.96MiB/s
# [ExtractAudio] Destination: videos\LARams\Stetson Bennett, DC Chris Shula & OC Mike LaFleur Address The Media As Rams Kick Off Week 2 Of OTAs.mp3
# Deleting original file videos\LARams\Stetson Bennett, DC Chris Shula & OC Mike LaFleur Address The Media As Rams Kick Off Week 2 Of OTAs.webm (pass -k to keep)
# yo
# yo1
# 2024-05-27 17:22:14.893165
# Checking 10 videos from the channel...https://www.youtube.com/c/MiamiDolphins/videos
# Adding video https://www.youtube.com/watch?v=KyJEx3neB6s, uploaded on 2024-05-28 00:00:00
# Skipping video https://www.youtube.com/watch?v=hOGKvSQFEZs, uploaded on 2024-05-21 00:00:00
# 2024-05-27 17:22:20.216452
# Checking 10 videos from the channel...https://www.youtube.com/c/MiamiDolphins/streams
# Skipping video https://www.youtube.com/watch?v=7s184tOiMvI, uploaded on 2024-05-28 00:00:00
# Downloading audio for https://www.youtube.com/watch?v=KyJEx3neB6s
# [youtube] Extracting URL: https://www.youtube.com/watch?v=KyJEx3neB6s
# [youtube] KyJEx3neB6s: Downloading webpage
# [youtube] KyJEx3neB6s: Downloading ios player API JSON
# [youtube] KyJEx3neB6s: Downloading android player API JSON
# [youtube] KyJEx3neB6s: Downloading m3u8 information
# [info] KyJEx3neB6s: Downloading 1 format(s): 251
# [download] Destination: videos\MiamiDolphins\Durham Smythe, Anthony Walker Jr., and Liam Eichenberg meet with the media ｜ Miami Dolphins.webm
# [download] 100% of    2.57MiB in 00:00:00 at 7.78MiB/s
# [ExtractAudio] Destination: videos\MiamiDolphins\Durham Smythe, Anthony Walker Jr., and Liam Eichenberg meet with the media ｜ Miami Dolphins.mp3
# Deleting original file videos\MiamiDolphins\Durham Smythe, Anthony Walker Jr., and Liam Eichenberg meet with the media ｜ Miami Dolphins.webm (pass -k to keep)
# yo
# yo1
# 2024-05-27 17:22:27.460477
# Checking 10 videos from the channel...https://www.youtube.com/c/NewOrleansSaints/videos
# Adding video https://www.youtube.com/watch?v=B0SXlh1aDkE, uploaded on 2024-05-28 00:00:00
# Adding video https://www.youtube.com/watch?v=XpV2By1klhU, uploaded on 2024-05-28 00:00:00
# Adding video https://www.youtube.com/watch?v=TtjqLXIBHdY, uploaded on 2024-05-28 00:00:00
# Adding video https://www.youtube.com/watch?v=B2BzsfZflJs, uploaded on 2024-05-28 00:00:00
# Adding video https://www.youtube.com/watch?v=-iawRUtlQIo, uploaded on 2024-05-28 00:00:00
# Adding video https://www.youtube.com/watch?v=-EYNNZq8lCE, uploaded on 2024-05-28 00:00:00
# Adding video https://www.youtube.com/watch?v=CVA1-gEpuzw, uploaded on 2024-05-28 00:00:00
# Skipping video https://www.youtube.com/watch?v=sUv_mrewXbc, uploaded on 2024-05-26 00:00:00
# 2024-05-27 17:22:46.770433
# Checking 10 videos from the channel...https://www.youtube.com/c/NewOrleansSaints/streams
# Adding video https://www.youtube.com/watch?v=TLM9d1Ok-v0, uploaded on 2024-05-28 00:00:00
# Skipping video https://www.youtube.com/watch?v=uwdB1Jnjm1o, uploaded on 2024-05-21 00:00:00
# Downloading audio for https://www.youtube.com/watch?v=B0SXlh1aDkE
# [youtube] Extracting URL: https://www.youtube.com/watch?v=B0SXlh1aDkE
# [youtube] B0SXlh1aDkE: Downloading webpage
# [youtube] B0SXlh1aDkE: Downloading ios player API JSON
# [youtube] B0SXlh1aDkE: Downloading android player API JSON
# [youtube] B0SXlh1aDkE: Downloading m3u8 information
# [info] B0SXlh1aDkE: Downloading 1 format(s): 251
# [download] Destination: videos\NewOrleansSaints\2024 Saints OTAs Practice Report 5⧸28⧸24.webm
# [download] 100% of    3.17MiB in 00:00:00 at 8.43MiB/s
# [ExtractAudio] Destination: videos\NewOrleansSaints\2024 Saints OTAs Practice Report 5⧸28⧸24.mp3
# Deleting original file videos\NewOrleansSaints\2024 Saints OTAs Practice Report 5⧸28⧸24.webm (pass -k to keep)
# Downloading audio for https://www.youtube.com/watch?v=XpV2By1klhU
# [youtube] Extracting URL: https://www.youtube.com/watch?v=XpV2By1klhU
# [youtube] XpV2By1klhU: Downloading webpage
# [youtube] XpV2By1klhU: Downloading ios player API JSON
# [youtube] XpV2By1klhU: Downloading android player API JSON
# [youtube] XpV2By1klhU: Downloading m3u8 information
# [info] XpV2By1klhU: Downloading 1 format(s): 251
# [download] Destination: videos\NewOrleansSaints\Taysom Hill talks his role in offense, learning new scheme ｜ 2024 Saints OTAs 5⧸28⧸24.webm
# [download] 100% of    6.11MiB in 00:00:00 at 7.22MiB/s
# [ExtractAudio] Destination: videos\NewOrleansSaints\Taysom Hill talks his role in offense, learning new scheme ｜ 2024 Saints OTAs 5⧸28⧸24.mp3
# Deleting original file videos\NewOrleansSaints\Taysom Hill talks his role in offense, learning new scheme ｜ 2024 Saints OTAs 5⧸28⧸24.webm (pass -k to keep)
# Downloading audio for https://www.youtube.com/watch?v=TtjqLXIBHdY
# [youtube] Extracting URL: https://www.youtube.com/watch?v=TtjqLXIBHdY
# [youtube] TtjqLXIBHdY: Downloading webpage
# [youtube] TtjqLXIBHdY: Downloading ios player API JSON
# [youtube] TtjqLXIBHdY: Downloading android player API JSON
# [youtube] TtjqLXIBHdY: Downloading m3u8 information
# [info] TtjqLXIBHdY: Downloading 1 format(s): 251
# [download] Destination: videos\NewOrleansSaints\Trevor Penning talks switch to right side, Klint Kubiak's scheme ｜ 2024 Saints OTAs 5⧸28⧸24.webm
# [download] 100% of    3.60MiB in 00:00:00 at 11.19MiB/s
# [ExtractAudio] Destination: videos\NewOrleansSaints\Trevor Penning talks switch to right side, Klint Kubiak's scheme ｜ 2024 Saints OTAs 5⧸28⧸24.mp3
# Deleting original file videos\NewOrleansSaints\Trevor Penning talks switch to right side, Klint Kubiak's scheme ｜ 2024 Saints OTAs 5⧸28⧸24.webm (pass -k to keep)
# Downloading audio for https://www.youtube.com/watch?v=B2BzsfZflJs
# [youtube] Extracting URL: https://www.youtube.com/watch?v=B2BzsfZflJs
# [youtube] B2BzsfZflJs: Downloading webpage
# [youtube] B2BzsfZflJs: Downloading ios player API JSON
# [youtube] B2BzsfZflJs: Downloading android player API JSON
# [youtube] B2BzsfZflJs: Downloading m3u8 information
# [info] B2BzsfZflJs: Downloading 1 format(s): 251
# [download] Destination: videos\NewOrleansSaints\Demario Davis talks faith event with Derek Carr, roster additions ｜ 2024 Saints OTAs 5⧸28⧸24.webm
# [download] 100% of   12.77MiB in 00:00:01 at 10.45MiB/s
# [ExtractAudio] Destination: videos\NewOrleansSaints\Demario Davis talks faith event with Derek Carr, roster additions ｜ 2024 Saints OTAs 5⧸28⧸24.mp3
# Deleting original file videos\NewOrleansSaints\Demario Davis talks faith event with Derek Carr, roster additions ｜ 2024 Saints OTAs 5⧸28⧸24.webm (pass -k to keep)
# Downloading audio for https://www.youtube.com/watch?v=-iawRUtlQIo
# [youtube] Extracting URL: https://www.youtube.com/watch?v=-iawRUtlQIo
# [youtube] -iawRUtlQIo: Downloading webpage
# [youtube] -iawRUtlQIo: Downloading ios player API JSON
# [youtube] -iawRUtlQIo: Downloading android player API JSON
# [youtube] -iawRUtlQIo: Downloading m3u8 information
# [info] -iawRUtlQIo: Downloading 1 format(s): 251
# [download] Destination: videos\NewOrleansSaints\2024 New Orleans Saints OTAs Highlights 5⧸28⧸24.webm
# [download] 100% of  868.46KiB in 00:00:00 at 2.86MiB/s
# [ExtractAudio] Destination: videos\NewOrleansSaints\2024 New Orleans Saints OTAs Highlights 5⧸28⧸24.mp3
# Deleting original file videos\NewOrleansSaints\2024 New Orleans Saints OTAs Highlights 5⧸28⧸24.webm (pass -k to keep)
# Downloading audio for https://www.youtube.com/watch?v=-EYNNZq8lCE
# [youtube] Extracting URL: https://www.youtube.com/watch?v=-EYNNZq8lCE
# [youtube] -EYNNZq8lCE: Downloading webpage
# [youtube] -EYNNZq8lCE: Downloading ios player API JSON
# [youtube] -EYNNZq8lCE: Downloading android player API JSON
# [youtube] -EYNNZq8lCE: Downloading m3u8 information
# [info] -EYNNZq8lCE: Downloading 1 format(s): 251
# [download] Destination: videos\NewOrleansSaints\Darren Rizzi talks new kickoff rule preparations ｜ 2024 Saints OTAs 5⧸28⧸24.webm
# [download] 100% of    3.03MiB in 00:00:00 at 9.31MiB/s
# [ExtractAudio] Destination: videos\NewOrleansSaints\Darren Rizzi talks new kickoff rule preparations ｜ 2024 Saints OTAs 5⧸28⧸24.mp3
# Deleting original file videos\NewOrleansSaints\Darren Rizzi talks new kickoff rule preparations ｜ 2024 Saints OTAs 5⧸28⧸24.webm (pass -k to keep)
# Downloading audio for https://www.youtube.com/watch?v=CVA1-gEpuzw
# [youtube] Extracting URL: https://www.youtube.com/watch?v=CVA1-gEpuzw
# [youtube] CVA1-gEpuzw: Downloading webpage
# [youtube] CVA1-gEpuzw: Downloading ios player API JSON
# [youtube] CVA1-gEpuzw: Downloading android player API JSON
# [youtube] CVA1-gEpuzw: Downloading m3u8 information
# [info] CVA1-gEpuzw: Downloading 1 format(s): 251
# [download] Destination: videos\NewOrleansSaints\Dennis Allen talks Roster ｜ 2024 Saints OTAs 5⧸28⧸24.webm
# [download] 100% of   11.15MiB in 00:00:01 at 8.10MiB/s
# [ExtractAudio] Destination: videos\NewOrleansSaints\Dennis Allen talks Roster ｜ 2024 Saints OTAs 5⧸28⧸24.mp3
# Deleting original file videos\NewOrleansSaints\Dennis Allen talks Roster ｜ 2024 Saints OTAs 5⧸28⧸24.webm (pass -k to keep)
# Downloading audio for https://www.youtube.com/watch?v=TLM9d1Ok-v0
# [youtube] Extracting URL: https://www.youtube.com/watch?v=TLM9d1Ok-v0
# [youtube] TLM9d1Ok-v0: Downloading webpage
# [youtube] TLM9d1Ok-v0: Downloading ios player API JSON
# [youtube] TLM9d1Ok-v0: Downloading android player API JSON
# [youtube] TLM9d1Ok-v0: Downloading m3u8 information
# [info] TLM9d1Ok-v0: Downloading 1 format(s): 251
# [download] Destination: videos\NewOrleansSaints\LIVE： 2024 New Orleans Saints OTAs ｜ Week 2.webm
# [download] 100% of   11.37MiB in 00:00:01 at 7.10MiB/s
# [ExtractAudio] Destination: videos\NewOrleansSaints\LIVE： 2024 New Orleans Saints OTAs ｜ Week 2.mp3
# Deleting original file videos\NewOrleansSaints\LIVE： 2024 New Orleans Saints OTAs ｜ Week 2.webm (pass -k to keep)
# yo
# yo1
# 2024-05-27 17:23:59.663125
# Checking 10 videos from the channel...https://www.youtube.com/c/NewYorkGiants/videos
# Skipping video https://www.youtube.com/watch?v=m6UJpftCOVQ, uploaded on 2024-05-23 00:00:00
# 2024-05-27 17:24:02.290763
# Checking 10 videos from the channel...https://www.youtube.com/c/NewYorkGiants/streams
# Skipping video https://www.youtube.com/watch?v=QhycxXCuNis, uploaded on 2024-04-27 00:00:00
# yo
# yo1
# 2024-05-27 17:24:05.072287
# Checking 10 videos from the channel...https://www.youtube.com/c/nyjets/videos
# Skipping video https://www.youtube.com/watch?v=I7pJOWvHi5s, uploaded on 2024-05-24 00:00:00
# 2024-05-27 17:24:07.754939
# Checking 10 videos from the channel...https://www.youtube.com/c/nyjets/streams
# ERROR: [youtube] 40YG4nr6I2Y: The following content is not available on this app.. Watch on the latest version of YouTube.
# Error processing video https://www.youtube.com/watch?v=40YG4nr6I2Y: ERROR: [youtube] 40YG4nr6I2Y: The following content is not available on this app.. Watch on the latest version of YouTube.
# Skipping video https://www.youtube.com/watch?v=NNr3v6tbLAw, uploaded on 2024-05-22 00:00:00
# yo
# yo1
# 2024-05-27 17:24:11.322204
# Checking 10 videos from the channel...https://www.youtube.com/c/packers/videos
# Adding video https://www.youtube.com/watch?v=cAJ4oXN9osg, uploaded on 2024-05-28 00:00:00
# Skipping video https://www.youtube.com/watch?v=oNOqgxp95go, uploaded on 2024-05-23 00:00:00
# 2024-05-27 17:24:16.306489
# Checking 10 videos from the channel...https://www.youtube.com/c/packers/streams
# Skipping video https://www.youtube.com/watch?v=P0ZL2Xaalj0, uploaded on 2024-05-21 00:00:00
# Downloading audio for https://www.youtube.com/watch?v=cAJ4oXN9osg
# [youtube] Extracting URL: https://www.youtube.com/watch?v=cAJ4oXN9osg
# [youtube] cAJ4oXN9osg: Downloading webpage
# [youtube] cAJ4oXN9osg: Downloading ios player API JSON
# [youtube] cAJ4oXN9osg: Downloading android player API JSON
# [youtube] cAJ4oXN9osg: Downloading m3u8 information
# [info] cAJ4oXN9osg: Downloading 1 format(s): 251
# [download] Destination: videos\packers\Packers Daily： One of the guys.webm
# [download] 100% of    1.68MiB in 00:00:00 at 6.96MiB/s
# [ExtractAudio] Destination: videos\packers\Packers Daily： One of the guys.mp3
# Deleting original file videos\packers\Packers Daily： One of the guys.webm (pass -k to keep)
# yo
# yo1
# 2024-05-27 17:24:23.219920
# Checking 10 videos from the channel...https://www.youtube.com/c/patriots/videos
# Skipping video https://www.youtube.com/watch?v=OI5-Hu-vHm0, uploaded on 2024-05-23 00:00:00
# 2024-05-27 17:24:25.748230
# Checking 10 videos from the channel...https://www.youtube.com/c/patriots/streams
# ERROR: [youtube] 5x722e-sv8Q: The following content is not available on this app.. Watch on the latest version of YouTube.
# Error processing video https://www.youtube.com/watch?v=5x722e-sv8Q: ERROR: [youtube] 5x722e-sv8Q: The following content is not available on this app.. Watch on the latest version of YouTube.
# ERROR: [youtube] GalMazzkgdw: The following content is not available on this app.. Watch on the latest version of YouTube.
# Error processing video https://www.youtube.com/watch?v=GalMazzkgdw: ERROR: [youtube] GalMazzkgdw: The following content is not available on this app.. Watch on the latest version of YouTube.
# Adding video https://www.youtube.com/watch?v=YKdx8cmcdVM, uploaded on 2024-05-28 00:00:00
# Skipping video https://www.youtube.com/watch?v=D3itzfQ5zrs, uploaded on 2024-05-23 00:00:00
# Downloading audio for https://www.youtube.com/watch?v=YKdx8cmcdVM
# [youtube] Extracting URL: https://www.youtube.com/watch?v=YKdx8cmcdVM
# [youtube] YKdx8cmcdVM: Downloading webpage
# [youtube] YKdx8cmcdVM: Downloading ios player API JSON
# [youtube] YKdx8cmcdVM: Downloading android player API JSON
# [youtube] YKdx8cmcdVM: Downloading MPD manifest
# [info] YKdx8cmcdVM: Downloading 1 format(s): 140
# [dashsegments] Total fragments: 1448
# [download] Destination: videos\patriots\LIVE： Patriots Unfiltered： Previewing Upcoming OTAs, Proposed Restructured Offseason Schedule.m4a
# [download] 100% of  113.18MiB in 00:01:45 at 1.07MiB/s
# [FixupM4a] Correcting container of "videos\patriots\LIVE： Patriots Unfiltered： Previewing Upcoming OTAs, Proposed Restructured Offseason Schedule.m4a"
# [FixupDuplicateMoov] Fixing duplicate MOOV atoms of "videos\patriots\LIVE： Patriots Unfiltered： Previewing Upcoming OTAs, Proposed Restructured Offseason Schedule.m4a"
# [ExtractAudio] Destination: videos\patriots\LIVE： Patriots Unfiltered： Previewing Upcoming OTAs, Proposed Restructured Offseason Schedule.mp3
# Deleting original file videos\patriots\LIVE： Patriots Unfiltered： Previewing Upcoming OTAs, Proposed Restructured Offseason Schedule.m4a (pass -k to keep)
# yo
# yo1
# 2024-05-27 17:27:18.328066
# Checking 10 videos from the channel...https://www.youtube.com/c/raiders/videos
# Skipping video https://www.youtube.com/watch?v=Txqy_txKNA8, uploaded on 2024-05-22 00:00:00
# 2024-05-27 17:27:20.849226
# Checking 10 videos from the channel...https://www.youtube.com/c/raiders/streams
# Skipping video https://www.youtube.com/watch?v=O1FymcP173U, uploaded on 2024-05-21 00:00:00
# yo
# yo1
# 2024-05-27 17:27:23.314603
# Checking 10 videos from the channel...https://www.youtube.com/c/Seahawks/videos
# Skipping video https://www.youtube.com/watch?v=MywdKbVuCTU, uploaded on 2024-05-17 00:00:00
# 2024-05-27 17:27:26.159252
# Checking 10 videos from the channel...https://www.youtube.com/c/Seahawks/streams
# Skipping video https://www.youtube.com/watch?v=fDH9AQtgAgs, uploaded on 2024-02-15 00:00:00
# yo
# yo1
# 2024-05-27 17:27:29.281945
# Checking 10 videos from the channel...https://www.youtube.com/c/steelers/videos
# Adding video https://www.youtube.com/watch?v=fav9CtVTyCA, uploaded on 2024-05-28 00:00:00
# Adding video https://www.youtube.com/watch?v=KzfEcjTZWxs, uploaded on 2024-05-28 00:00:00
# Skipping video https://www.youtube.com/watch?v=IanNw35Jl1s, uploaded on 2024-05-23 00:00:00
# 2024-05-27 17:27:36.555067
# Checking 10 videos from the channel...https://www.youtube.com/c/steelers/streams
# Skipping video https://www.youtube.com/watch?v=tohrrgQURNI, uploaded on 2024-05-23 00:00:00
# Downloading audio for https://www.youtube.com/watch?v=fav9CtVTyCA
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fav9CtVTyCA
# [youtube] fav9CtVTyCA: Downloading webpage
# [youtube] fav9CtVTyCA: Downloading ios player API JSON
# [youtube] fav9CtVTyCA: Downloading android player API JSON
# [youtube] fav9CtVTyCA: Downloading m3u8 information
# [info] fav9CtVTyCA: Downloading 1 format(s): 251
# [download] Destination: videos\steelers\Austin III, Heyward, Seumalo, Frazier Media Availabilities (May 28) ｜ Pittsburgh Steelers.webm
# [download] 100% of   10.84MiB in 00:00:00 at 17.65MiB/s
# [ExtractAudio] Destination: videos\steelers\Austin III, Heyward, Seumalo, Frazier Media Availabilities (May 28) ｜ Pittsburgh Steelers.mp3
# Deleting original file videos\steelers\Austin III, Heyward, Seumalo, Frazier Media Availabilities (May 28) ｜ Pittsburgh Steelers.webm (pass -k to keep)
# Downloading audio for https://www.youtube.com/watch?v=KzfEcjTZWxs
# [youtube] Extracting URL: https://www.youtube.com/watch?v=KzfEcjTZWxs
# [youtube] KzfEcjTZWxs: Downloading webpage
# [youtube] KzfEcjTZWxs: Downloading ios player API JSON
# [youtube] KzfEcjTZWxs: Downloading android player API JSON
# [youtube] KzfEcjTZWxs: Downloading m3u8 information
# [info] KzfEcjTZWxs: Downloading 1 format(s): 251
# [download] Destination: videos\steelers\Casey Hampton on his football career and more ｜ Steelers Time Machine.webm
# [download] 100% of    9.79MiB in 00:00:01 at 9.10MiB/s
# [ExtractAudio] Destination: videos\steelers\Casey Hampton on his football career and more ｜ Steelers Time Machine.mp3
# Deleting original file videos\steelers\Casey Hampton on his football career and more ｜ Steelers Time Machine.webm (pass -k to keep)
# yo
# yo1
# 2024-05-27 17:28:00.506509
# Checking 10 videos from the channel...https://www.youtube.com/c/Titans/videos
# Adding video https://www.youtube.com/watch?v=umSo2dEgbys, uploaded on 2024-05-28 00:00:00
# Skipping video https://www.youtube.com/watch?v=urYEgOdzMfQ, uploaded on 2024-05-23 00:00:00
# 2024-05-27 17:28:05.888521
# Checking 10 videos from the channel...https://www.youtube.com/c/Titans/streams
# Skipping video https://www.youtube.com/watch?v=3LPKMldvuyE, uploaded on 2022-04-21 00:00:00
# Downloading audio for https://www.youtube.com/watch?v=umSo2dEgbys
# [youtube] Extracting URL: https://www.youtube.com/watch?v=umSo2dEgbys
# [youtube] umSo2dEgbys: Downloading webpage
# [youtube] umSo2dEgbys: Downloading ios player API JSON
# [youtube] umSo2dEgbys: Downloading android player API JSON
# [youtube] umSo2dEgbys: Downloading m3u8 information
# [info] umSo2dEgbys: Downloading 1 format(s): 251
# [download] Destination: videos\Titans\Brian Callahan OTA Practice ｜ Mic'd Up.webm
# [download] 100% of    1.84MiB in 00:00:00 at 2.06MiB/s
# [ExtractAudio] Destination: videos\Titans\Brian Callahan OTA Practice ｜ Mic'd Up.mp3
# Deleting original file videos\Titans\Brian Callahan OTA Practice ｜ Mic'd Up.webm (pass -k to keep)
# yo
# yo1
# 2024-05-27 17:28:13.076373
# Checking 10 videos from the channel...https://www.youtube.com/c/vikings/videos
# Adding video https://www.youtube.com/watch?v=WJVZ0abd3d4, uploaded on 2024-05-28 00:00:00
# Skipping video https://www.youtube.com/watch?v=QxXO-cqQTAg, uploaded on 2024-05-23 00:00:00
# 2024-05-27 17:28:17.688314
# Checking 10 videos from the channel...https://www.youtube.com/c/vikings/streams
# Skipping video https://www.youtube.com/watch?v=ij4jp_lcYCg, uploaded on 2023-07-31 00:00:00
# Downloading audio for https://www.youtube.com/watch?v=WJVZ0abd3d4
# [youtube] Extracting URL: https://www.youtube.com/watch?v=WJVZ0abd3d4
# [youtube] WJVZ0abd3d4: Downloading webpage
# [youtube] WJVZ0abd3d4: Downloading ios player API JSON
# [youtube] WJVZ0abd3d4: Downloading android player API JSON
# [youtube] WJVZ0abd3d4: Downloading m3u8 information
# [info] WJVZ0abd3d4: Downloading 1 format(s): 251
# [download] Destination: videos\vikings\2024 OTA Practice No. 4 Highlights ｜ Minnesota Vikings.webm
# [download] 100% of  862.95KiB in 00:00:00 at 4.73MiB/s
# [ExtractAudio] Destination: videos\vikings\2024 OTA Practice No. 4 Highlights ｜ Minnesota Vikings.mp3
# Deleting original file videos\vikings\2024 OTA Practice No. 4 Highlights ｜ Minnesota Vikings.webm (pass -k to keep)

# %%
# def download_audio(url, output_path):
#     ydl_opts = {
#         'outtmpl': output_path,
#         'format': 'bestaudio/best',
#         'postprocessors': [{
#             'key': 'FFmpegExtractAudio',
#             'preferredcodec': 'mp3',
#             'preferredquality': '192',
#         }],
#         'ffmpeg_location' : ffmpeg_location,
#     }
#     try:
#         with yt_dlp.YoutubeDL(ydl_opts) as ydl:
#             ydl.download([url])
#     except Exception as e:
#         print(f"Error downloading {url}: {e}")

# %%
# ffmpeg_location = 'c:/users/12505/anaconda3/lib/site-packages/ffmpeg/bin'
# # List of YouTube URLs to download
# urls = [
#     'https://www.youtube.com/watch?v=r7jgEE6t1u4&ab_channel=NewOrleansSaints',
# ]

# # Directory to save downloaded videos
# output_dir = '/videos/%(title)s.%(ext)s'

# for url in urls:
#     download_audio(url, output_dir)
